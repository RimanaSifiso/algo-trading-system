# %%
import requests 
import pandas as pd
import json

import sys
sys.path.append("../") 

from constants import ACCOUNT_ID, API_KEY, OANDA_URL

from typing import List, Dict, AnyStr, Optional

# %%
# create a new session
session = requests.Session()

session_headers = {
    "Authorization": f"Bearer {API_KEY}",
    "Content-Type": "application/json"
} 

# this makes sure that all requests are made with the above headers, as required by Oanda API
session.headers.update(session_headers)

# %%
def build_url(paths: List | None, params: Dict = {}) -> str:
    url = OANDA_URL
    for path in paths:
        url += f"/{path}"

    for param, value in params.items():
        url += f"?{param}={value}"
        url += "&"

    return url

# %%
build_url(paths=['accounts', ACCOUNT_ID, 'pricing'], params={'instruments': 'EUR_USD'})
# Out:
# 'https://api-fxpractice.oanda.com/v3/accounts/101-004-29541766-001/pricing?instruments=EUR_USD&'

# %% [markdown]
# # 1. Fetch Trading Instruments (Pairs)

# %%
params = dict(
    count=10,granularity='H1',
)

url = build_url(['accounts', ACCOUNT_ID, 'instruments'])

response = session.get(url=url, params=None, headers=None)
data = response.json()

# %%
data.keys()
# Out:
# dict_keys(['instruments', 'lastTransactionID'])

# %%
response.status_code
# Out:
# 200

# %%
instruments_list = data['instruments']
len(instruments_list)
# Out:
# 123

# %%
instruments_list[0].keys()
# Out:
# dict_keys(['name', 'type', 'displayName', 'pipLocation', 'displayPrecision', 'tradeUnitsPrecision', 'minimumTradeSize', 'maximumTrailingStopDistance', 'minimumTrailingStopDistance', 'maximumPositionSize', 'maximumOrderUnits', 'marginRate', 'guaranteedStopLossOrderMode', 'tags', 'financing'])

# %%
keys_of_interest = ['name', 'type', 'displayName', 'pipLocation', 'displayPrecision', 'tradeUnitsPrecision', 'marginRate']

instruments_obj = {}


for i in instruments_list:
    key = i['name']
    instruments_obj[key] = { k: i[k] for k in keys_of_interest}

instruments_obj['USD_ZAR']
# Out:
# {'name': 'USD_ZAR',
#  'type': 'CURRENCY',
#  'displayName': 'USD/ZAR',
#  'pipLocation': -4,
#  'displayPrecision': 5,
#  'tradeUnitsPrecision': 0,
#  'marginRate': '0.05'}

# %%
# save the instruments as json file
with open("../data/instruments.json", 'w') as f:
    f.write(json.dumps(instruments_obj, indent=2))

print("instruments.json saved successfully!")
# Out:
# instruments.json saved successfully!

# %% [markdown]
# # 2. Fetch Candles (Historical Data)

# %%
def fetch_candles(pair_name: str, count: int = 10, granularity: str = 'H1') -> tuple[int, list]:
    url = build_url(paths=['instruments', pair_name, 'candles'])
    params = dict(
        count=count, 
        granularity=granularity,
        price="MBA"                 # mid, bid and ask prices
    )
    response = session.get(url=url, params=params, data=None, headers=None)
    data = response.json()
    
    if response.status_code == 200:
        if 'candles' in data:
            data = data['candles']
        else: 
            data = []

    return response.status_code, data

# %%
code, data = fetch_candles('USD_ZAR')
code
# Out:
# 200

# %%
len(data)
# Out:
# 10

# %%
def get_candles_df(data: list) -> pd.DataFrame:

    if len(data) == 0: return pd.DataFrame()       # in case data is empty

    final_data = []

    prices = ['mid', 'bid', 'ask']
    ohlc = ['o', 'h', 'l', 'c']

    for candle in data:
        if not candle['complete']: continue 
        new_dict = {}
        new_dict['time'] = candle['time']

        for p in prices:
            for o in ohlc:
                new_dict[f'{p}_{o}'] = float(candle[p][o])

        new_dict['volume'] = candle['volume']
        final_data.append(new_dict)

    df = pd.DataFrame(final_data)
    df['time'] = pd.to_datetime(df['time'])
    return df

# %%
get_candles_df(fetch_candles('EUR_USD', 100, 'H4')[1])
# Out:
#                         time    mid_o    mid_h    mid_l    mid_c    bid_o  \
# 0  2025-09-11 05:00:00+00:00  1.16996  1.16996  1.16838  1.16921  1.16988
# 1  2025-09-11 09:00:00+00:00  1.16920  1.17210  1.16606  1.17152  1.16912
# 2  2025-09-11 13:00:00+00:00  1.17152  1.17461  1.17140  1.17365  1.17144
# 3  2025-09-11 17:00:00+00:00  1.17366  1.17398  1.17278  1.17355  1.17358
# 4  2025-09-11 21:00:00+00:00  1.17333  1.17406  1.17273  1.17330  1.17306
# ..                       ...      ...      ...      ...      ...      ...
# 95 2025-10-03 01:00:00+00:00  1.17243  1.17293  1.17162  1.17180  1.17235
# 96 2025-10-03 05:00:00+00:00  1.17180  1.17446  1.17149  1.17402  1.17171
# 97 2025-10-03 09:00:00+00:00  1.17402  1.17429  1.17270  1.17395  1.17394
# 98 2025-10-03 13:00:00+00:00  1.17396  1.17594  1.17327  1.17398  1.17387
# 99 2025-10-03 17:00:00+00:00  1.17398  1.17445  1.17268  1.17429  1.17391
#
#       bid_h    bid_l    bid_c    ask_o    ask_h    ask_l    ask_c  volume
# 0   1.16988  1.16830  1.16913  1.17004  1.17004  1.16846  1.16929   25427
# 1   1.17202  1.16587  1.17145  1.16929  1.17218  1.16618  1.17160   47243
# 2   1.17453  1.17131  1.17357  1.17160  1.17469  1.17148  1.17373   50660
# 3   1.17390  1.17269  1.17346  1.17373  1.17405  1.17286  1.17364   14890
# 4   1.17397  1.17264  1.17321  1.17360  1.17417  1.17281  1.17338    8924
# ..      ...      ...      ...      ...      ...      ...      ...     ...
# 95  1.17285  1.17154  1.17172  1.17251  1.17301  1.17171  1.17188   13591
# 96  1.17439  1.17140  1.17395  1.17188  1.17454  1.17158  1.17410   24354
# 97  1.17422  1.17259  1.17387  1.17410  1.17437  1.17279  1.17403   25225
# 98  1.17586  1.17320  1.17391  1.17404  1.17602  1.17334  1.17406   43076
# 99  1.17437  1.17260  1.17417  1.17405  1.17466  1.17276  1.17441   14030
#
# [100 rows x 14 columns]

# %%
get_candles_df([])
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
def create_data_file(pair_name: str, count: int = 10, granularity: str = 'H1'):
    status_code, data = fetch_candles(pair_name=pair_name, count=count, granularity=granularity)
    
    if status_code != 200:
        print("Something went wrong while fetching data!")
        print(f"Status code: {status_code}\n Instrument: {pair_name}")
        print(data)
        return
    
    if len(data) == 0:
        print("Request successfull, but no data was returned!")
        print(f"Status code: {status_code}\n Instrument: {pair_name}")
        return
    
    df = get_candles_df(data=data)
    min_time = df.time.dt.date.min()
    max_time = df.time.dt.date.max()
    df_filename = f"{pair_name}_{granularity}_{min_time}_{max_time}.csv"
    df.to_csv(f"../data/history/{df_filename}", index=False)
    print(f"{df_filename} saved! || {df.shape[0]} {granularity} candles  ||  {min_time}  -  {max_time}")

# %%
create_data_file('EUR_USD')
# Out:
# EUR_USD_H1_2025-10-03_2025-10-03.csv saved! // 10 H1 candles  //  2025-10-03  -  2025-10-03

# %%
currencies = ['EUR', 'USD', 'NZD', 'ZAR', 'JPY', 'CAD', 'GBP', 'AUD']
granularities = ['H1', 'H4']

for p1 in currencies:
    for p2 in currencies:
        if p1 == p2: continue
        pair = f"{p1}_{p2}"
        if pair in instruments_obj.keys():
            for granularity in granularities:
                create_data_file(pair_name=pair, count=4001, granularity=granularity)
# Out:
# EUR_USD_H1_2025-02-13_2025-10-03.csv saved! // 4001 H1 candles  //  2025-02-13  -  2025-10-03
# EUR_USD_H4_2023-03-10_2025-10-03.csv saved! // 4001 H4 candles  //  2023-03-10  -  2025-10-03
# EUR_NZD_H1_2025-02-13_2025-10-03.csv saved! // 4001 H1 candles  //  2025-02-13  -  2025-10-03
# EUR_NZD_H4_2023-03-10_2025-10-03.csv saved! // 4001 H4 candles  //  2023-03-10  -  2025-10-03
# EUR_ZAR_H1_2025-02-13_2025-10-03.csv saved! // 4001 H1 candles  //  2025-02-13  -  2025-10-03
# EUR_ZAR_H4_2023-03-10_2025-10-03.csv saved! // 4001 H4 candles  //  2023-03-10  -  2025-10-03
# EUR_JPY_H1_2025-02-13_2025-10-03.csv saved! // 4001 H1 candles  //  2025-02-13  -  2025-10-03
# EUR_JPY_H4_2023-03-10_2025-10-03.csv saved! // 4001 H4 candles  //  2023-03-10  -  2025-10-03
# EUR_CAD_H1_2025-02-13_2025-10-03.csv saved! // 4001 H1 candles  //  2025-02-13  -  2025-10-03
# EUR_CAD_H4_2023-03-10_2025-10-03.csv saved! // 4001 H4 candles  //  2023-03-10  -  2025-10-03
# EUR_GBP_H1_2025-02-13_2025-10-03.csv saved! // 4001 H1 candles  //  2025-02-13  -  2025-10-03
# EUR_GBP_H4_2023-03-10_2025-10-03.csv saved! // 4001 H4 candles  //  2023-03-10  -  2025-10-03
# EUR_AUD_H1_2025-02-13_2025-10-03.csv saved! // 4001 H1 candles  //  2025-02-13  -  2025-10-03
# EUR_AUD_H4_2023-03-10_2025-10-03.csv saved! // 4001 H4 candles  //  2023-03-10  -  2025-10-03
# USD_ZAR_H1_2025-02-13_2025-10-03.csv saved! // 4001 H1 candles  //  2025-02-13  -  2025-10-03
# USD_ZAR_H4_2023-03-10_2025-10-03.csv saved! // 4001 H4 candles  //  2023-03-10  -  2025-10-03
# USD_JPY_H1_2025-02-13_2025-10-03.csv saved! // 4001 H1 candles  //  2025-02-13  -  2025-10-03
# USD_JPY_H4_2023-03-10_2025-10-03.csv saved! // 4001 H4 candles  //  2023-03-10  -  2025-10-03
# USD_CAD_H1_2025-02-13_2025-10-03.csv saved! // 4001 H1 candles  //  2025-02-13  -  2025-10-03
# USD_CAD_H4_2023-03-10_2025-10-03.csv saved! // 4001 H4 candles  //  2023-03-10  -  2025-10-03
# NZD_USD_H1_2025-02-13_2025-10-03.csv saved! // 4001 H1 candles  //  2025-02-13  -  2025-10-03
# NZD_USD_H4_2023-03-10_2025-10-03.csv saved! // 4001 H4 candles  //  2023-03-10  -  2025-10-03
# NZD_JPY_H1_2025-02-13_2025-10-03.csv saved! // 4001 H1 candles  //  2025-02-13  -  2025-10-03
# NZD_JPY_H4_2023-03-10_2025-10-03.csv saved! // 4001 H4 candles  //  2023-03-10  -  2025-10-03
# NZD_CAD_H1_2025-02-13_2025-10-03.csv saved! // 4001 H1 candles  //  2025-02-13  -  2025-10-03
# NZD_CAD_H4_2023-03-10_2025-10-03.csv saved! // 4001 H4 candles  //  2023-03-10  -  2025-10-03
# ZAR_JPY_H1_2025-02-13_2025-10-03.csv saved! // 4001 H1 candles  //  2025-02-13  -  2025-10-03
# ZAR_JPY_H4_2023-03-10_2025-10-03.csv saved! // 4001 H4 candles  //  2023-03-10  -  2025-10-03
# CAD_JPY_H1_2025-02-13_2025-10-03.csv saved! // 4001 H1 candles  //  2025-02-13  -  2025-10-03
# CAD_JPY_H4_2023-03-10_2025-10-03.csv saved! // 4001 H4 candles  //  2023-03-10  -  2025-10-03
# GBP_USD_H1_2025-02-13_2025-10-03.csv saved! // 4001 H1 candles  //  2025-02-13  -  2025-10-03
# GBP_USD_H4_2023-03-10_2025-10-03.csv saved! // 4001 H4 candles  //  2023-03-10  -  2025-10-03
# GBP_NZD_H1_2025-02-13_2025-10-03.csv saved! // 4001 H1 candles  //  2025-02-13  -  2025-10-03
# GBP_NZD_H4_2023-03-10_2025-10-03.csv saved! // 4001 H4 candles  //  2023-03-10  -  2025-10-03
# GBP_ZAR_H1_2025-02-13_2025-10-03.csv saved! // 4001 H1 candles  //  2025-02-13  -  2025-10-03
# GBP_ZAR_H4_2023-03-10_2025-10-03.csv saved! // 4001 H4 candles  //  2023-03-10  -  2025-10-03
# GBP_JPY_H1_2025-02-13_2025-10-03.csv saved! // 4001 H1 candles  //  2025-02-13  -  2025-10-03
# GBP_JPY_H4_2023-03-10_2025-10-03.csv saved! // 4001 H4 candles  //  2023-03-10  -  2025-10-03
# GBP_CAD_H1_2025-02-13_2025-10-03.csv saved! // 4001 H1 candles  //  2025-02-13  -  2025-10-03
# GBP_CAD_H4_2023-03-10_2025-10-03.csv saved! // 4001 H4 candles  //  2023-03-10  -  2025-10-03
# GBP_AUD_H1_2025-02-13_2025-10-03.csv saved! // 4001 H1 candles  //  2025-02-13  -  2025-10-03
# GBP_AUD_H4_2023-03-10_2025-10-03.csv saved! // 4001 H4 candles  //  2023-03-10  -  2025-10-03
# AUD_USD_H1_2025-02-13_2025-10-03.csv saved! // 4001 H1 candles  //  2025-02-13  -  2025-10-03
# AUD_USD_H4_2023-03-10_2025-10-03.csv saved! // 4001 H4 candles  //  2023-03-10  -  2025-10-03
# AUD_NZD_H1_2025-02-13_2025-10-03.csv saved! // 4001 H1 candles  //  2025-02-13  -  2025-10-03
# AUD_NZD_H4_2023-03-10_2025-10-03.csv saved! // 4001 H4 candles  //  2023-03-10  -  2025-10-03
# AUD_JPY_H1_2025-02-13_2025-10-03.csv saved! // 4001 H1 candles  //  2025-02-13  -  2025-10-03
# AUD_JPY_H4_2023-03-10_2025-10-03.csv saved! // 4001 H4 candles  //  2023-03-10  -  2025-10-03
# AUD_CAD_H1_2025-02-13_2025-10-03.csv saved! // 4001 H1 candles  //  2025-02-13  -  2025-10-03
# AUD_CAD_H4_2023-03-10_2025-10-03.csv saved! // 4001 H4 candles  //  2023-03-10  -  2025-10-03

# %%
instruments_obj
# Out:
# {'TRY_JPY': {'name': 'TRY_JPY',
#   'type': 'CURRENCY',
#   'displayName': 'TRY/JPY',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.25'},
#  'AUD_JPY': {'name': 'AUD_JPY',
#   'type': 'CURRENCY',
#   'displayName': 'AUD/JPY',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'USB02Y_USD': {'name': 'USB02Y_USD',
#   'type': 'CFD',
#   'displayName': 'US 2Y T-Note',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.20'},
#  'XAU_USD': {'name': 'XAU_USD',
#   'type': 'METAL',
#   'displayName': 'Gold',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'USD_CNH': {'name': 'USD_CNH',
#   'type': 'CURRENCY',
#   'displayName': 'USD/CNH',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'NZD_JPY': {'name': 'NZD_JPY',
#   'type': 'CURRENCY',
#   'displayName': 'NZD/JPY',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'EUR_GBP': {'name': 'EUR_GBP',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/GBP',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.03333333333333'},
#  'XAG_GBP': {'name': 'XAG_GBP',
#   'type': 'METAL',
#   'displayName': 'Silver/GBP',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.10'},
#  'XAU_NZD': {'name': 'XAU_NZD',
#   'type': 'METAL',
#   'displayName': 'Gold/NZD',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'CHF_HKD': {'name': 'CHF_HKD',
#   'type': 'CURRENCY',
#   'displayName': 'CHF/HKD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.1'},
#  'CN50_USD': {'name': 'CN50_USD',
#   'type': 'CFD',
#   'displayName': 'China A50',
#   'pipLocation': 0,
#   'displayPrecision': 1,
#   'tradeUnitsPrecision': 1,
#   'marginRate': '0.10'},
#  'USD_CZK': {'name': 'USD_CZK',
#   'type': 'CURRENCY',
#   'displayName': 'USD/CZK',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'US30_USD': {'name': 'US30_USD',
#   'type': 'CFD',
#   'displayName': 'US Wall St 30',
#   'pipLocation': 0,
#   'displayPrecision': 1,
#   'tradeUnitsPrecision': 1,
#   'marginRate': '0.05'},
#  'NZD_HKD': {'name': 'NZD_HKD',
#   'type': 'CURRENCY',
#   'displayName': 'NZD/HKD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.1'},
#  'JP225Y_JPY': {'name': 'JP225Y_JPY',
#   'type': 'CFD',
#   'displayName': 'Japan 225 (JPY)',
#   'pipLocation': 0,
#   'displayPrecision': 1,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'EUR_NOK': {'name': 'EUR_NOK',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/NOK',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'USD_CAD': {'name': 'USD_CAD',
#   'type': 'CURRENCY',
#   'displayName': 'USD/CAD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.03333333333333'},
#  'EUR_AUD': {'name': 'EUR_AUD',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/AUD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'EUR_SGD': {'name': 'EUR_SGD',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/SGD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'USD_HKD': {'name': 'USD_HKD',
#   'type': 'CURRENCY',
#   'displayName': 'USD/HKD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.1'},
#  'CH20_CHF': {'name': 'CH20_CHF',
#   'type': 'CFD',
#   'displayName': 'Switzerland 20',
#   'pipLocation': 0,
#   'displayPrecision': 1,
#   'tradeUnitsPrecision': 1,
#   'marginRate': '0.1'},
#  'CAD_HKD': {'name': 'CAD_HKD',
#   'type': 'CURRENCY',
#   'displayName': 'CAD/HKD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.1'},
#  'XAG_CHF': {'name': 'XAG_CHF',
#   'type': 'METAL',
#   'displayName': 'Silver/CHF',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.10'},
#  'USD_CHF': {'name': 'USD_CHF',
#   'type': 'CURRENCY',
#   'displayName': 'USD/CHF',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.04'},
#  'XAG_HKD': {'name': 'XAG_HKD',
#   'type': 'METAL',
#   'displayName': 'Silver/HKD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.1'},
#  'AUD_HKD': {'name': 'AUD_HKD',
#   'type': 'CURRENCY',
#   'displayName': 'AUD/HKD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.1'},
#  'ESPIX_EUR': {'name': 'ESPIX_EUR',
#   'type': 'CFD',
#   'displayName': 'Spain 35',
#   'pipLocation': 0,
#   'displayPrecision': 1,
#   'tradeUnitsPrecision': 1,
#   'marginRate': '0.1'},
#  'NZD_CHF': {'name': 'NZD_CHF',
#   'type': 'CURRENCY',
#   'displayName': 'NZD/CHF',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'AUD_CHF': {'name': 'AUD_CHF',
#   'type': 'CURRENCY',
#   'displayName': 'AUD/CHF',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'GBP_CHF': {'name': 'GBP_CHF',
#   'type': 'CURRENCY',
#   'displayName': 'GBP/CHF',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.04'},
#  'USD_THB': {'name': 'USD_THB',
#   'type': 'CURRENCY',
#   'displayName': 'USD/THB',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'XAU_JPY': {'name': 'XAU_JPY',
#   'type': 'METAL',
#   'displayName': 'Gold/JPY',
#   'pipLocation': 1,
#   'displayPrecision': 0,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'XAU_HKD': {'name': 'XAU_HKD',
#   'type': 'METAL',
#   'displayName': 'Gold/HKD',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'EUR_HKD': {'name': 'EUR_HKD',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/HKD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.1'},
#  'CHF_JPY': {'name': 'CHF_JPY',
#   'type': 'CURRENCY',
#   'displayName': 'CHF/JPY',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.04'},
#  'GBP_HKD': {'name': 'GBP_HKD',
#   'type': 'CURRENCY',
#   'displayName': 'GBP/HKD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.1'},
#  'EUR_NZD': {'name': 'EUR_NZD',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/NZD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'XAG_AUD': {'name': 'XAG_AUD',
#   'type': 'METAL',
#   'displayName': 'Silver/AUD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.10'},
#  'WTICO_USD': {'name': 'WTICO_USD',
#   'type': 'CFD',
#   'displayName': 'West Texas Oil',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.10'},
#  'XAG_NZD': {'name': 'XAG_NZD',
#   'type': 'METAL',
#   'displayName': 'Silver/NZD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.10'},
#  'AUD_SGD': {'name': 'AUD_SGD',
#   'type': 'CURRENCY',
#   'displayName': 'AUD/SGD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'EUR_JPY': {'name': 'EUR_JPY',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/JPY',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.03333333333333'},
#  'EUR_TRY': {'name': 'EUR_TRY',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/TRY',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.25'},
#  'USD_JPY': {'name': 'USD_JPY',
#   'type': 'CURRENCY',
#   'displayName': 'USD/JPY',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.03333333333333'},
#  'SGD_JPY': {'name': 'SGD_JPY',
#   'type': 'CURRENCY',
#   'displayName': 'SGD/JPY',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'GBP_ZAR': {'name': 'GBP_ZAR',
#   'type': 'CURRENCY',
#   'displayName': 'GBP/ZAR',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'XAG_JPY': {'name': 'XAG_JPY',
#   'type': 'METAL',
#   'displayName': 'Silver/JPY',
#   'pipLocation': 0,
#   'displayPrecision': 1,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.10'},
#  'ZAR_JPY': {'name': 'ZAR_JPY',
#   'type': 'CURRENCY',
#   'displayName': 'ZAR/JPY',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'USD_SEK': {'name': 'USD_SEK',
#   'type': 'CURRENCY',
#   'displayName': 'USD/SEK',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'GBP_SGD': {'name': 'GBP_SGD',
#   'type': 'CURRENCY',
#   'displayName': 'GBP/SGD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'XAU_SGD': {'name': 'XAU_SGD',
#   'type': 'METAL',
#   'displayName': 'Gold/SGD',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'CAD_CHF': {'name': 'CAD_CHF',
#   'type': 'CURRENCY',
#   'displayName': 'CAD/CHF',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.04'},
#  'US2000_USD': {'name': 'US2000_USD',
#   'type': 'CFD',
#   'displayName': 'US Russ 2000',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 1,
#   'marginRate': '0.10'},
#  'SPX500_USD': {'name': 'SPX500_USD',
#   'type': 'CFD',
#   'displayName': 'US SPX 500',
#   'pipLocation': 0,
#   'displayPrecision': 1,
#   'tradeUnitsPrecision': 1,
#   'marginRate': '0.05'},
#  'AUD_NZD': {'name': 'AUD_NZD',
#   'type': 'CURRENCY',
#   'displayName': 'AUD/NZD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'USB30Y_USD': {'name': 'USB30Y_USD',
#   'type': 'CFD',
#   'displayName': 'US T-Bond',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.20'},
#  'BCO_USD': {'name': 'BCO_USD',
#   'type': 'CFD',
#   'displayName': 'Brent Crude Oil',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.10'},
#  'HKD_JPY': {'name': 'HKD_JPY',
#   'type': 'CURRENCY',
#   'displayName': 'HKD/JPY',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.1'},
#  'XAU_XAG': {'name': 'XAU_XAG',
#   'type': 'METAL',
#   'displayName': 'Gold/Silver',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.1'},
#  'HK33_HKD': {'name': 'HK33_HKD',
#   'type': 'CFD',
#   'displayName': 'Hong Kong 33',
#   'pipLocation': 0,
#   'displayPrecision': 1,
#   'tradeUnitsPrecision': 1,
#   'marginRate': '0.10'},
#  'USB10Y_USD': {'name': 'USB10Y_USD',
#   'type': 'CFD',
#   'displayName': 'US 10Y T-Note',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.20'},
#  'EU50_EUR': {'name': 'EU50_EUR',
#   'type': 'CFD',
#   'displayName': 'Europe 50',
#   'pipLocation': 0,
#   'displayPrecision': 1,
#   'tradeUnitsPrecision': 1,
#   'marginRate': '0.05'},
#  'USD_NOK': {'name': 'USD_NOK',
#   'type': 'CURRENCY',
#   'displayName': 'USD/NOK',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'XAU_GBP': {'name': 'XAU_GBP',
#   'type': 'METAL',
#   'displayName': 'Gold/GBP',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'GBP_AUD': {'name': 'GBP_AUD',
#   'type': 'CURRENCY',
#   'displayName': 'GBP/AUD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'USD_PLN': {'name': 'USD_PLN',
#   'type': 'CURRENCY',
#   'displayName': 'USD/PLN',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'XCU_USD': {'name': 'XCU_USD',
#   'type': 'CFD',
#   'displayName': 'Copper',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.10'},
#  'EUR_ZAR': {'name': 'EUR_ZAR',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/ZAR',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'NZD_USD': {'name': 'NZD_USD',
#   'type': 'CURRENCY',
#   'displayName': 'NZD/USD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'XAG_EUR': {'name': 'XAG_EUR',
#   'type': 'METAL',
#   'displayName': 'Silver/EUR',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.10'},
#  'DE30_EUR': {'name': 'DE30_EUR',
#   'type': 'CFD',
#   'displayName': 'Germany 30',
#   'pipLocation': 0,
#   'displayPrecision': 1,
#   'tradeUnitsPrecision': 1,
#   'marginRate': '0.05'},
#  'USD_ZAR': {'name': 'USD_ZAR',
#   'type': 'CURRENCY',
#   'displayName': 'USD/ZAR',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'CAD_JPY': {'name': 'CAD_JPY',
#   'type': 'CURRENCY',
#   'displayName': 'CAD/JPY',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.03333333333333'},
#  'CAD_SGD': {'name': 'CAD_SGD',
#   'type': 'CURRENCY',
#   'displayName': 'CAD/SGD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'USD_HUF': {'name': 'USD_HUF',
#   'type': 'CURRENCY',
#   'displayName': 'USD/HUF',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'EUR_CAD': {'name': 'EUR_CAD',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/CAD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.03333333333333'},
#  'NATGAS_USD': {'name': 'NATGAS_USD',
#   'type': 'CFD',
#   'displayName': 'Natural Gas',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.10'},
#  'FR40_EUR': {'name': 'FR40_EUR',
#   'type': 'CFD',
#   'displayName': 'France 40',
#   'pipLocation': 0,
#   'displayPrecision': 1,
#   'tradeUnitsPrecision': 1,
#   'marginRate': '0.05'},
#  'DE10YB_EUR': {'name': 'DE10YB_EUR',
#   'type': 'CFD',
#   'displayName': 'Bund',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.20'},
#  'CHF_ZAR': {'name': 'CHF_ZAR',
#   'type': 'CURRENCY',
#   'displayName': 'CHF/ZAR',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'USD_DKK': {'name': 'USD_DKK',
#   'type': 'CURRENCY',
#   'displayName': 'USD/DKK',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'NAS100_USD': {'name': 'NAS100_USD',
#   'type': 'CFD',
#   'displayName': 'US Nas 100',
#   'pipLocation': 0,
#   'displayPrecision': 1,
#   'tradeUnitsPrecision': 1,
#   'marginRate': '0.05'},
#  'XAU_CAD': {'name': 'XAU_CAD',
#   'type': 'METAL',
#   'displayName': 'Gold/CAD',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'XPD_USD': {'name': 'XPD_USD',
#   'type': 'CFD',
#   'displayName': 'Palladium',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.10'},
#  'EUR_HUF': {'name': 'EUR_HUF',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/HUF',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'XPT_USD': {'name': 'XPT_USD',
#   'type': 'CFD',
#   'displayName': 'Platinum',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.10'},
#  'XAU_AUD': {'name': 'XAU_AUD',
#   'type': 'METAL',
#   'displayName': 'Gold/AUD',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'CORN_USD': {'name': 'CORN_USD',
#   'type': 'CFD',
#   'displayName': 'Corn',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.10'},
#  'XAU_EUR': {'name': 'XAU_EUR',
#   'type': 'METAL',
#   'displayName': 'Gold/EUR',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'CHINAH_HKD': {'name': 'CHINAH_HKD',
#   'type': 'CFD',
#   'displayName': 'China H Shares',
#   'pipLocation': 0,
#   'displayPrecision': 1,
#   'tradeUnitsPrecision': 1,
#   'marginRate': '0.1'},
#  'NL25_EUR': {'name': 'NL25_EUR',
#   'type': 'CFD',
#   'displayName': 'Netherlands 25',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 1,
#   'marginRate': '0.10'},
#  'EUR_CHF': {'name': 'EUR_CHF',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/CHF',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.04'},
#  'EUR_DKK': {'name': 'EUR_DKK',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/DKK',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.1'},
#  'SOYBN_USD': {'name': 'SOYBN_USD',
#   'type': 'CFD',
#   'displayName': 'Soybeans',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.10'},
#  'EUR_USD': {'name': 'EUR_USD',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/USD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.03333333333333'},
#  'SG30_SGD': {'name': 'SG30_SGD',
#   'type': 'CFD',
#   'displayName': 'Singapore 30',
#   'pipLocation': -1,
#   'displayPrecision': 2,
#   'tradeUnitsPrecision': 1,
#   'marginRate': '0.10'},
#  'AU200_AUD': {'name': 'AU200_AUD',
#   'type': 'CFD',
#   'displayName': 'Australia 200',
#   'pipLocation': 0,
#   'displayPrecision': 1,
#   'tradeUnitsPrecision': 1,
#   'marginRate': '0.05'},
#  'XAG_CAD': {'name': 'XAG_CAD',
#   'type': 'METAL',
#   'displayName': 'Silver/CAD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.10'},
#  'JP225_USD': {'name': 'JP225_USD',
#   'type': 'CFD',
#   'displayName': 'Japan 225',
#   'pipLocation': 0,
#   'displayPrecision': 1,
#   'tradeUnitsPrecision': 1,
#   'marginRate': '0.05'},
#  'XAG_SGD': {'name': 'XAG_SGD',
#   'type': 'METAL',
#   'displayName': 'Silver/SGD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.10'},
#  'EUR_CZK': {'name': 'EUR_CZK',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/CZK',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'XAG_USD': {'name': 'XAG_USD',
#   'type': 'METAL',
#   'displayName': 'Silver',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.10'},
#  'NZD_CAD': {'name': 'NZD_CAD',
#   'type': 'CURRENCY',
#   'displayName': 'NZD/CAD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'SGD_CHF': {'name': 'SGD_CHF',
#   'type': 'CURRENCY',
#   'displayName': 'SGD/CHF',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'WHEAT_USD': {'name': 'WHEAT_USD',
#   'type': 'CFD',
#   'displayName': 'Wheat',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.10'},
#  'GBP_JPY': {'name': 'GBP_JPY',
#   'type': 'CURRENCY',
#   'displayName': 'GBP/JPY',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.03333333333333'},
#  'USD_TRY': {'name': 'USD_TRY',
#   'type': 'CURRENCY',
#   'displayName': 'USD/TRY',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.25'},
#  'GBP_PLN': {'name': 'GBP_PLN',
#   'type': 'CURRENCY',
#   'displayName': 'GBP/PLN',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'AUD_USD': {'name': 'AUD_USD',
#   'type': 'CURRENCY',
#   'displayName': 'AUD/USD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'GBP_USD': {'name': 'GBP_USD',
#   'type': 'CURRENCY',
#   'displayName': 'GBP/USD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.03333333333333'},
#  'USD_MXN': {'name': 'USD_MXN',
#   'type': 'CURRENCY',
#   'displayName': 'USD/MXN',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'UK100_GBP': {'name': 'UK100_GBP',
#   'type': 'CFD',
#   'displayName': 'UK 100',
#   'pipLocation': 0,
#   'displayPrecision': 1,
#   'tradeUnitsPrecision': 1,
#   'marginRate': '0.05'},
#  'GBP_CAD': {'name': 'GBP_CAD',
#   'type': 'CURRENCY',
#   'displayName': 'GBP/CAD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.03333333333333'},
#  'UK10YB_GBP': {'name': 'UK10YB_GBP',
#   'type': 'CFD',
#   'displayName': 'UK 10Y Gilt',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.20'},
#  'AUD_CAD': {'name': 'AUD_CAD',
#   'type': 'CURRENCY',
#   'displayName': 'AUD/CAD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'EUR_PLN': {'name': 'EUR_PLN',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/PLN',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'SUGAR_USD': {'name': 'SUGAR_USD',
#   'type': 'CFD',
#   'displayName': 'Sugar',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.10'},
#  'USB05Y_USD': {'name': 'USB05Y_USD',
#   'type': 'CFD',
#   'displayName': 'US 5Y T-Note',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.20'},
#  'GBP_NZD': {'name': 'GBP_NZD',
#   'type': 'CURRENCY',
#   'displayName': 'GBP/NZD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'XAU_CHF': {'name': 'XAU_CHF',
#   'type': 'METAL',
#   'displayName': 'Gold/CHF',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'EUR_SEK': {'name': 'EUR_SEK',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/SEK',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'USD_SGD': {'name': 'USD_SGD',
#   'type': 'CURRENCY',
#   'displayName': 'USD/SGD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'NZD_SGD': {'name': 'NZD_SGD',
#   'type': 'CURRENCY',
#   'displayName': 'NZD/SGD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'}}

# %%
today=pd.to_datetime("2025-10-10")

# %%
import datetime 

min(today + datetime.timedelta(seconds=240), today)
# Out:
# Timestamp('2025-10-10 00:00:00')

# %%
pd.to_datetime(today)
# Out:
# Timestamp('2025-10-10 00:00:00')

# %% [markdown]
# import date
